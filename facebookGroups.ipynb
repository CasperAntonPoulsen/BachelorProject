# %%
import pandas as pd
from os import listdir

# %%
listdir("FacebookGroups")
# Out:
# ['group-posts61f2b29d9ffbd-DRNyheder.xlsx',
#  'group-posts61f2b2f67a010-tv2nyhederne.xlsx',
#  'group-posts61f2b3096c119-ekstrabladet.xlsx',
#  'group-posts61f2b34293724-berlingske.xlsx',
#  'group-posts61f2b35feb99b-ditbt.xlsx']

# %%
workingDir = "FacebookGroups"

# %%
dataframes = [pd.read_excel(workingDir + "/" + file, header=5) for file in listdir(workingDir)]
df = pd.concat(dataframes)
df_sorted = df.sort_values(by="Comments Count", ascending=False)

# %%
df_sorted
# Out:
#      Unnamed: 0  Unnamed: 1                Post ID            Name  \
# 43           44         NaN   ID: 5943942922287965  TV 2 NYHEDERNE
# 21           22         NaN  ID: 10159088756448520   Ekstra Bladet
# 2             3         NaN   ID: 5938489486166642  TV 2 NYHEDERNE
# 46           47         NaN  ID: 10159090421418520   Ekstra Bladet
# 25           26         NaN  ID: 10159088990863520   Ekstra Bladet
# ..          ...         ...                    ...             ...
# 1             2         NaN  ID: 10159087637868520   Ekstra Bladet
# 21           22         NaN  ID: 10158617913238133      Berlingske
# 34           35         NaN  ID: 10158619142423133      Berlingske
# 46           47         NaN   ID: 5799070970120073            B.T.
# 145         146         NaN  ID: 10158627318818133      Berlingske
#
#        Publication Date                                            Message  \
# 43  2022-01-26 10:14:52                                        Hvem tør? 😱
# 21  2022-01-24 14:08:02  Hvad vil du helst have - Dan Jørgensen eller e...
# 2   2022-01-25 07:30:12       Der er stor forskel på København og Jylland.
# 46  2022-01-25 11:02:19  Ifølge Jyllands-Posten vil Mette Frederiksen p...
# 25  2022-01-24 16:52:17  Er lønnen til dem, der deler reklamer og ugeav...
# ..                  ...                                                ...
# 1   2022-01-23 21:45:24  Nicolaj Thomsen har skrevet navnet på sin nye ...
# 21  2022-01-21 22:19:00  Gyserfilmen står stærkt i dansk film. Det vise...
# 34  2022-01-22 14:50:35  Her er historien om flyselskabet, hvor absolut...
# 46  2022-01-27 14:38:55  »Jeg talte og talte og tænkte, at det måtte da...
# 145 2022-01-27 07:44:54  »Efter at have set den, synes jeg faktisk, at ...
#
#                                        Post Url (view source)  Comments Count  \
# 43    https://www.facebook.com/5943942922287965     view post           17876
# 21   https://www.facebook.com/10159088756448520     view post            5681
# 2     https://www.facebook.com/5938489486166642     view post            4635
# 46   https://www.facebook.com/10159090421418520     view post            4075
# 25   https://www.facebook.com/10159088990863520     view post            3246
# ..                                          ...           ...             ...
# 1    https://www.facebook.com/10159087637868520     view post               0
# 21   https://www.facebook.com/10158617913238133     view post               0
# 34   https://www.facebook.com/10158619142423133     view post               0
# 46    https://www.facebook.com/5799070970120073     view post               0
# 145  https://www.facebook.com/10158627318818133     view post               0
#
#      Reactions Count  Shares Count  Views Count    LIKE  SUPPORT   LOVE  \
# 43              4436           445            0  3348.0      6.0  325.0
# 21              1792            85            0   818.0      2.0    7.0
# 2               2512           101            0   680.0      2.0   14.0
# 46              4320           372            0  3236.0     21.0  304.0
# 25              1918           103            0  1838.0      1.0    4.0
# ..               ...           ...          ...     ...      ...    ...
# 1                 14             0            0    13.0      NaN    NaN
# 21                 6             0            0     5.0      1.0    NaN
# 34                 4             0            0     3.0      1.0    NaN
# 46                 4             0            0     4.0      NaN    NaN
# 145                2             0            0     2.0      NaN    NaN
#
#      ANGER    HAHA  SORRY    WOW
# 43     2.0    25.0    7.0  723.0
# 21    13.0   925.0    7.0   20.0
# 2    107.0  1197.0   26.0  486.0
# 46   112.0   558.0   35.0   54.0
# 25    25.0    35.0    5.0   10.0
# ..     ...     ...    ...    ...
# 1      NaN     NaN    NaN    1.0
# 21     NaN     NaN    NaN    NaN
# 34     NaN     NaN    NaN    NaN
# 46     NaN     NaN    NaN    NaN
# 145    NaN     NaN    NaN    NaN
#
# [435 rows x 19 columns]
